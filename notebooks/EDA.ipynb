# %%
import pandas as pd

car_data = pd.read_csv('vehicles_us.csv')

# Ver las primeras filas y los tipos de columnas
print(car_data.shape)        # cuántas filas y columnas
car_data.head()              # primeras 5 filas

# %%
car_data.info()              # tipos de datos por columna
